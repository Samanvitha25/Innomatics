# %%
a = input("Enter sentence:")
b = a.split()    #Convert sentence into words
c = set(b)     #Convert list to set to remove duplicates
d = len(c)     #Count unique words
print("Unique words count:",d)
print("Unique words:",c)
# Out:
# Enter sentence: python is easy and python is powerful
# Unique words count: 5
# Unique words: {'easy', 'python', 'is', 'powerful', 'and'}

# %%
a = {"Ravi": 75000,
    "Anita": 68000,
    "Kiran": 72000}
b = max(a.values())        
c = max(a, key=a.get)
print("Highest Salary:",c,"-",b)
# Out:
# Highest Salary: Ravi - 75000

# %%
a = [45, 22, 89, 10, 66]
b = a[0]  
c = a[0]  
for d in a:
    if d > b:
        b = d
    if d < c:
        c = d
print("List:", a)
print("Max:", b)
print("Min:", c)
# Out:
# List: [45, 22, 89, 10, 66]
# Max: 89
# Min: 10

# %%
a = [450, 1200, 899, 1500, 300]
b = 0  
for c in a:
    if c > 1000:
        b = b + 1
print("Products above 1000:", b)
# Out:
# Products above 1000: 2

# %%
a = ["P", "P", "A", "P", "P"]
b = 0  
for c in a:
    if c == "P":
        b =b +1
d = len(a)
e = (b/d)*100
print("Attendance Percentage:",e)
# Out:
# Attendance Percentage: 80.0

# %%
a = [9876543210, 9123456789, 9876543210]
b = set(a)
print("Unique phone numbers:",b)
# Out:
# Unique phone numbers: {9876543210, 9123456789}

# %%
a = [10, 20, 30]
b = tuple(a)
print("Tuple:",b)
# Out:
# Tuple: (10, 20, 30)

# %%
a = {"Ravi": 75000,
    "Anita": 68000,
    "Kiran": 72000}
b = "Ravi"
if b in a:
    print("Employee exists")
else:
    print("Employee does not exist")
# Out:
# Employee exists

# %%
a = [70, 80, 75, 65]
b = 0
for c in a:
    b = b + c
d = len(a)
e = b / d
print("Average Marks:", e)
# Out:
# Average Marks: 72.5
